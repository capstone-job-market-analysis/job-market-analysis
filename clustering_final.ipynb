# %% [markdown]
# ---
# # Clustering Level 3 Industries in TX
#
# Adam Talbot
#
# ---

# %%
# standard imports
import matplotlib.pyplot as plt

# pickle for reloading model object
import pickle

# visualization settings
plt.rc('figure', figsize=(13, 7))
plt.rc('font', size=16)
plt.style.use('seaborn-darkgrid')

# custom modules
import explore as e

# %% [markdown]
# ---
# ## Load Trained Model
# ---

# %%
# load model
filename = 'finalized_model.sav'
loaded_model = pickle.load(open(filename, 'rb'))
loaded_model
# Out:
# KMeans(n_clusters=7, random_state=527)

# %% [markdown]
# ---
# ## Cluster and Visualize Clusters
# ---

# %%
e.load_acquire_to_cluster_lines(loaded_model)

# %% [markdown]
# Thoughts:
# - Most industries were mildly or moderately affected, but recovered quickly.
# - Some were actually positively impacted.
# - Some were more severely affected and are still in the process of recovery.
#     - A subset of these were clustered into a separate cluster due to high seasonality.
# - Some are not yet recovering or are recovering very slowly.
# - Some were not affected at all.
